# %%
import pandas as pd
import numpy as np

# %%
mice_protein_data = pd.read_csv("mice_protein.csv")
mice_protein_data.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0   309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1   309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2   309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3   309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4   309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
#
#     pBRAF_N  pCAMKII_N   pCREB_N  ...   pCFOS_N     SYP_N  H3AcK18_N  \
# 0  0.177565   2.373744  0.232224  ...  0.108336  0.427099   0.114783
# 1  0.172817   2.292150  0.226972  ...  0.104315  0.441581   0.111974
# 2  0.175722   2.283337  0.230247  ...  0.106219  0.435777   0.111883
# 3  0.176463   2.152301  0.207004  ...  0.111262  0.391691   0.130405
# 4  0.173627   2.134014  0.192158  ...  0.110694  0.434154   0.118481
#
#      EGR1_N  H3MeK4_N    CaNA_N  Genotype  Treatment  Behavior   class
# ...

# %%
dataSet_columns = mice_protein_data.columns

# %%
print(dataSet_columns)
# Out:
# Index(['MouseID', 'DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N',
#        'pBRAF_N', 'pCAMKII_N', 'pCREB_N', 'pELK_N', 'pERK_N', 'pJNK_N',
#        'PKCA_N', 'pMEK_N', 'pNR1_N', 'pNR2A_N', 'pNR2B_N', 'pPKCAB_N',
#        'pRSK_N', 'AKT_N', 'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N',
#        'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N', 'RSK_N', 'APP_N', 'Bcatenin_N',
#        'SOD1_N', 'MTOR_N', 'P38_N', 'pMTOR_N', 'DSCR1_N', 'AMPKA_N', 'NR2B_N',
#        'pNUMB_N', 'RAPTOR_N', 'TIAM1_N', 'pP70S6_N', 'NUMB_N', 'P70S6_N',
#        'pGSK3B_N', 'pPKCG_N', 'CDK5_N', 'S6_N', 'ADARB1_N', 'AcetylH3K9_N',
#        'RRP1_N', 'BAX_N', 'ARC_N', 'ERBB4_N', 'nNOS_N', 'Tau_N', 'GFAP_N',
#        'GluR3_N', 'GluR4_N', 'IL1B_N', 'P3525_N', 'pCASP9_N', 'PSD95_N',
#        'SNCA_N', 'Ubiquitin_N', 'pGSK3B_Tyr216_N', 'SHH_N', 'BAD_N', 'BCL2_N',
#        'pS6_N', 'pCFOS_N', 'SYP_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N',
#        'CaNA_N', 'Genotype', 'Treatment', 'Behavior', 'class'],
# ...

# %%
mice_protein_data.describe()
# Out:
#           DYRK1A_N      ITSN1_N       BDNF_N        NR1_N       NR2A_N  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000
# mean      0.425810     0.617102     0.319088     2.297269     3.843934
# std       0.249362     0.251640     0.049383     0.347293     0.933100
# min       0.145327     0.245359     0.115181     1.330831     1.737540
# 25%       0.288121     0.473361     0.287444     2.057411     3.155678
# 50%       0.366378     0.565782     0.316564     2.296546     3.760855
# 75%       0.487711     0.698032     0.348197     2.528481     4.440011
# max       2.516367     2.602662     0.497160     3.757641     8.482553
#
#             pAKT_N      pBRAF_N    pCAMKII_N      pCREB_N       pELK_N  ...  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000  ...
# mean      0.233168     0.181846     3.537109     0.212574     1.428682  ...
# std       0.041634     0.027042     1.295169     0.032587     0.466904  ...
# ...

# %%
mice_protein_data.shape
# Out:
# (1080, 82)

# %%
#checking for datatypes
mice_protein_data.dtypes
# Out:
# MouseID       object
# DYRK1A_N     float64
# ITSN1_N      float64
# BDNF_N       float64
# NR1_N        float64
#               ...
# CaNA_N       float64
# Genotype      object
# Treatment     object
# Behavior      object
# class         object
# Length: 82, dtype: object

# %%
#Using value_counts to check for any extra white spaces in the categorical features

# %%
mice_protein_data["Genotype"].value_counts()
# Out:
# Control    570
# Ts65Dn     510
# Name: Genotype, dtype: int64

# %%
mice_protein_data["Behavior"].value_counts()
# Out:
# S/C    555
# C/S    525
# Name: Behavior, dtype: int64

# %%
mice_protein_data["Treatment"].value_counts()
# Out:
# Memantine    570
# Saline       510
# Name: Treatment, dtype: int64

# %%
mice_protein_data["class"].value_counts()
# Out:
# c-SC-m    150
# c-CS-m    150
# c-CS-s    135
# t-SC-m    135
# c-SC-s    135
# t-SC-s    135
# t-CS-m    135
# t-CS-s    105
# Name: class, dtype: int64

# %%
#checking for any impossible values
#few outliers detected and would be confirmed in data exploration
mice_protein_data.iloc[:,1:78]
# Out:
#       DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0     0.503644  0.747193  0.430175  2.816329  5.990152  0.218830  0.177565
# 1     0.514617  0.689064  0.411770  2.789514  5.685038  0.211636  0.172817
# 2     0.509183  0.730247  0.418309  2.687201  5.622059  0.209011  0.175722
# 3     0.442107  0.617076  0.358626  2.466947  4.979503  0.222886  0.176463
# 4     0.434940  0.617430  0.358802  2.365785  4.718679  0.213106  0.173627
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736  0.171262
# 1076  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274  0.182496
# 1077  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665  0.161435
# 1078  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897  0.173623
# 1079  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001  0.191811
#
# ...

# %%
mice_protein_data.isnull().sum
# Out:
# <bound method DataFrame.sum of       MouseID  DYRK1A_N  ITSN1_N  BDNF_N  NR1_N  NR2A_N  pAKT_N  pBRAF_N  \
# 0       False     False    False   False  False   False   False    False
# 1       False     False    False   False  False   False   False    False
# 2       False     False    False   False  False   False   False    False
# 3       False     False    False   False  False   False   False    False
# 4       False     False    False   False  False   False   False    False
# ...       ...       ...      ...     ...    ...     ...     ...      ...
# 1075    False     False    False   False  False   False   False    False
# 1076    False     False    False   False  False   False   False    False
# 1077    False     False    False   False  False   False   False    False
# 1078    False     False    False   False  False   False   False    False
# 1079    False     False    False   False  False   False   False    False
#
# ...

# %%
#checking for total number of null values
mice_protein_data.isnull().sum()
# Out:
# MouseID      0
# DYRK1A_N     3
# ITSN1_N      3
# BDNF_N       3
# NR1_N        3
#             ..
# CaNA_N       0
# Genotype     0
# Treatment    0
# Behavior     0
# class        0
# Length: 82, dtype: int64

# %%
#all the missing values are present in numerical data
mice_protein_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 82 columns):
# MouseID            1080 non-null object
# DYRK1A_N           1077 non-null float64
# ITSN1_N            1077 non-null float64
# BDNF_N             1077 non-null float64
# NR1_N              1077 non-null float64
# NR2A_N             1077 non-null float64
# pAKT_N             1077 non-null float64
# pBRAF_N            1077 non-null float64
# pCAMKII_N          1077 non-null float64
# pCREB_N            1077 non-null float64
# pELK_N             1077 non-null float64
# pERK_N             1077 non-null float64
# pJNK_N             1077 non-null float64
# PKCA_N             1077 non-null float64
# pMEK_N             1077 non-null float64
# pNR1_N             1077 non-null float64
# pNR2A_N            1077 non-null float64
# pNR2B_N            1077 non-null float64
# pPKCAB_N           1077 non-null float64
# pRSK_N             1077 non-null float64
# ...

# %%
#checking values in categorical data
for i in mice_protein_data.columns[78:82]:
    print(mice_protein_data[i].value_counts())
# Out:
# Control    570
# Ts65Dn     510
# Name: Genotype, dtype: int64
# Memantine    570
# Saline       510
# Name: Treatment, dtype: int64
# S/C    555
# C/S    525
# Name: Behavior, dtype: int64
# c-SC-m    150
# c-CS-m    150
# c-CS-s    135
# t-SC-m    135
# c-SC-s    135
# t-SC-s    135
# t-CS-m    135
# t-CS-s    105
# Name: class, dtype: int64

# %%
mice_protein_data.columns[0:78]
# Out:
# Index(['MouseID', 'DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N',
#        'pBRAF_N', 'pCAMKII_N', 'pCREB_N', 'pELK_N', 'pERK_N', 'pJNK_N',
#        'PKCA_N', 'pMEK_N', 'pNR1_N', 'pNR2A_N', 'pNR2B_N', 'pPKCAB_N',
#        'pRSK_N', 'AKT_N', 'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N',
#        'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N', 'RSK_N', 'APP_N', 'Bcatenin_N',
#        'SOD1_N', 'MTOR_N', 'P38_N', 'pMTOR_N', 'DSCR1_N', 'AMPKA_N', 'NR2B_N',
#        'pNUMB_N', 'RAPTOR_N', 'TIAM1_N', 'pP70S6_N', 'NUMB_N', 'P70S6_N',
#        'pGSK3B_N', 'pPKCG_N', 'CDK5_N', 'S6_N', 'ADARB1_N', 'AcetylH3K9_N',
#        'RRP1_N', 'BAX_N', 'ARC_N', 'ERBB4_N', 'nNOS_N', 'Tau_N', 'GFAP_N',
#        'GluR3_N', 'GluR4_N', 'IL1B_N', 'P3525_N', 'pCASP9_N', 'PSD95_N',
#        'SNCA_N', 'Ubiquitin_N', 'pGSK3B_Tyr216_N', 'SHH_N', 'BAD_N', 'BCL2_N',
#        'pS6_N', 'pCFOS_N', 'SYP_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N',
#        'CaNA_N'],
#       dtype='object')

# %%
mice_protein_data.describe()
# Out:
#           DYRK1A_N      ITSN1_N       BDNF_N        NR1_N       NR2A_N  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000
# mean      0.425810     0.617102     0.319088     2.297269     3.843934
# std       0.249362     0.251640     0.049383     0.347293     0.933100
# min       0.145327     0.245359     0.115181     1.330831     1.737540
# 25%       0.288121     0.473361     0.287444     2.057411     3.155678
# 50%       0.366378     0.565782     0.316564     2.296546     3.760855
# 75%       0.487711     0.698032     0.348197     2.528481     4.440011
# max       2.516367     2.602662     0.497160     3.757641     8.482553
#
#             pAKT_N      pBRAF_N    pCAMKII_N      pCREB_N       pELK_N  ...  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000  ...
# mean      0.233168     0.181846     3.537109     0.212574     1.428682  ...
# std       0.041634     0.027042     1.295169     0.032587     0.466904  ...
# ...

# %%
update_mice_protein_data = mice_protein_data.dropna(how='any', thresh=75)
update_mice_protein_data = mice_protein_data.fillna(update_mice_protein_data.mean())

# %%
#some values increased as expected, data is cleaned
update_mice_protein_data.describe()
# Out:
#           DYRK1A_N      ITSN1_N       BDNF_N        NR1_N       NR2A_N  \
# count  1080.000000  1080.000000  1080.000000  1080.000000  1080.000000
# mean      0.425810     0.617102     0.319088     2.297269     3.843934
# std       0.249015     0.251290     0.049314     0.346810     0.931802
# min       0.145327     0.245359     0.115181     1.330831     1.737540
# 25%       0.288163     0.473669     0.287650     2.059152     3.160287
# 50%       0.366540     0.566365     0.316703     2.297269     3.763306
# 75%       0.487574     0.697500     0.348039     2.528035     4.425107
# max       2.516367     2.602662     0.497160     3.757641     8.482553
#
#             pAKT_N      pBRAF_N    pCAMKII_N      pCREB_N       pELK_N  ...  \
# count  1080.000000  1080.000000  1080.000000  1080.000000  1080.000000  ...
# mean      0.233168     0.181846     3.537109     0.212574     1.428682  ...
# std       0.041577     0.027004     1.293368     0.032542     0.466254  ...
# ...

# %%
#data cleaned as required and ready to be explored
update_mice_protein_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 82 columns):
# MouseID            1080 non-null object
# DYRK1A_N           1080 non-null float64
# ITSN1_N            1080 non-null float64
# BDNF_N             1080 non-null float64
# NR1_N              1080 non-null float64
# NR2A_N             1080 non-null float64
# pAKT_N             1080 non-null float64
# pBRAF_N            1080 non-null float64
# pCAMKII_N          1080 non-null float64
# pCREB_N            1080 non-null float64
# pELK_N             1080 non-null float64
# pERK_N             1080 non-null float64
# pJNK_N             1080 non-null float64
# PKCA_N             1080 non-null float64
# pMEK_N             1080 non-null float64
# pNR1_N             1080 non-null float64
# pNR2A_N            1080 non-null float64
# pNR2B_N            1080 non-null float64
# pPKCAB_N           1080 non-null float64
# pRSK_N             1080 non-null float64
# ...

# %% [markdown]
# UNIVARIATE DATA EXPLORATION

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
update_mice_protein_data.columns[1:11]
# Out:
# Index(['DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N', 'pBRAF_N',
#        'pCAMKII_N', 'pCREB_N', 'pELK_N'],
#       dtype='object')

# %%
#getting an insight over distribution of different proteins
list = ["DYRK1A_N","ITSN1_N","BDNF_N","NR1_N","NR2A_N","pAKT_N","pBRAF_N","pCAMKII_N","pCREB_N","pELK_N"]
i = 0
for cols in update_mice_protein_data.columns[1:11]:
    plt.hist(update_mice_protein_data[cols], bins=30, edgecolor= "red", color = "green" )
    plt.title(list[i])
    plt.xlabel("Values")
    plt.ylabel("Count of Mice")
    plt.grid(True)
    plt.show()
    i+=1

# %%
#getting an insight over distribution of different proteins
list = ["SOD1_N","pPKCG_N","CaNA_N","Ubiquitin_N","APP_N","ITSN1_N","pERK_N","pCAMKII_N","ARC_N","DYRK1A_N","pPKCAB_N","Tau_N","P38_N","BRAF_N","pS6_N","pP70S6_N","pGSK3B_N", "pNUMB_N", "AKT_N", "S6_N", "AcetylH3K9_N"]
i = 0
# for cols in update_mice_protein_data.columns[1:11]:
while i<21:
    plt.hist(update_mice_protein_data[list[i]], bins=30, edgecolor= "red", color = "green" )
    plt.title(list[i])
    plt.xlabel("Values")
    plt.ylabel("Count of Mice")
    plt.grid(True)
    plt.show()
    i+=1

# %%
#plotting the count of mice didvied by Genotype
plt.bar(update_mice_protein_data["Genotype"].value_counts().keys(),update_mice_protein_data["Genotype"].value_counts(),color="#003f5c", edgecolor="black")
plt.title("Distribution based on Genotype")
plt.xlabel("Gentotype")
plt.ylabel("Number of measurements")
# Out:
# Text(0, 0.5, 'Number of measurements')

# %%
#plotting the count of mice divided by Treatments
update_mice_protein_data["Treatment"].value_counts()
plt.bar(update_mice_protein_data["Treatment"].value_counts().keys(),update_mice_protein_data["Treatment"].value_counts(),color="#003f5c", edgecolor="black")
plt.title("Distribution based on Treatment")
plt.xlabel("Treatment")
plt.ylabel("Number of measurements")
# Out:
# Text(0, 0.5, 'Number of measurements')

# %%
#plotting the count of mice divided by Behavior
update_mice_protein_data["Behavior"].value_counts()
plt.bar(update_mice_protein_data["Behavior"].value_counts().keys(),update_mice_protein_data["Behavior"].value_counts(),color="#003f5c", edgecolor="black")
# Out:
# <BarContainer object of 2 artists>

# %%
#Plotting the count of mice divided by class
update_mice_protein_data["class"].value_counts()
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9', 
                      '#C1F0F6', '#0099CC']
ax=plt.axes()
ax.set_facecolor('black')
plt.bar(update_mice_protein_data["class"].value_counts().keys(),update_mice_protein_data["class"].value_counts(),color=color_palette_list)
plt.title("Bar Chart for the Class attribute")
plt.xlabel("Types")
plt.ylabel("Count for Mice")
# Out:
# Text(0, 0.5, 'Count for Mice')

# %%
#Percentage of mice divided by Treatment
label = ["Memantine","Saline"]
size_gender = update_mice_protein_data["Treatment"].value_counts()*100/len(update_mice_protein_data)
plt.pie(size_gender, labels = label, autopct = "%1.1f%%", shadow = True, startangle = 90, explode= (0.1,0), colors = ["#F7B7A3","#EA5F89"])
plt.title("Representing percentage of mice subjected to Different Treatments")
plt.show()

# %%
#confirming the percentage
update_mice_protein_data["Treatment"].value_counts()
# Out:
# Memantine    570
# Saline       510
# Name: Treatment, dtype: int64

# %%
#plotting the percentage of mice by GenoType
label = ["Control","Ts65Dn"]
size_gender = update_mice_protein_data["Genotype"].value_counts()*100/len(update_mice_protein_data)
plt.pie(size_gender, labels = label, autopct = "%1.1f%%", shadow = True, startangle = 90, explode= (0.1,0), colors = ["lightblue","lightsteelblue"])
plt.title("Representing percentage of mice subjected to Different Genotype")
plt.show()

# %%
#confirming the genotype
update_mice_protein_data["Genotype"].value_counts()
# Out:
# Control    570
# Ts65Dn     510
# Name: Genotype, dtype: int64

# %%
#probability density of a particular protein
plt.violinplot(update_mice_protein_data["DYRK1A_N"], showmeans = True, showmedians = True)
plt.title("Violin Plot")
plt.grid(True)
plt.show()
#mean   - 0.4258 
#median - 0.36653

# %%
#probability density of a particular protein
plt.violinplot(update_mice_protein_data["ITSN1_N"], showmeans=True, showmedians=True)
plt.show()
# mean = 0.617
# median = 0.56636

# %%
update_mice_protein_data.columns[20:30]
# Out:
# Index(['AKT_N', 'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N', 'GSK3B_N',
#        'JNK_N', 'MEK_N', 'TRKA_N'],
#       dtype='object')

# %%
#probability density of a few proteins
list = ['APP_N', 'pCREB_N', 'SOD1_N', 'pERK_N']
j=0
k=1;
while j<4:
    #plt.subplot(5,2,k)
    plt.violinplot(update_mice_protein_data[list[j]], showmeans=True, showmedians=True)
    plt.title("Violin Plot for " + list[j])
    print("Mean - " + str(update_mice_protein_data[list[j]].mean()))
    print("Median - " + str(update_mice_protein_data[list[j]].median()) )
    plt.show()
    j+=1
    k+=1
# Out:
# Mean - 0.40480831895821745
# Median - 0.4021753775
# Mean - 0.21257393077251618
# Median - 0.2106809155
# Mean - 0.5426346438737231
# Median - 0.4460267275
# Mean - 0.5459040975626734
# Median - 0.444222841

# %%
#probability density of a few proteins
list = ['AKT_N', 'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N', 'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N']
j=0
k=1;
for i in update_mice_protein_data.columns[20:30]:
    #plt.subplot(5,2,k)
    plt.violinplot(update_mice_protein_data[i], showmeans=True, showmedians=True)
    plt.title("Violin Plot for " + list[j])
    print("Mean - " + str(update_mice_protein_data[i].mean()))
    print("Median - " + str(update_mice_protein_data[i].median()) )
    plt.show()
    j+=1
    k+=1
# Out:
# Mean - 0.6822364889637896
# Median - 0.6822364889637896
# Mean - 0.37851854251532124
# Median - 0.3267299935
# Mean - 0.36335662714763245
# Median - 0.3604826335
# Mean - 0.18049157903714033
# Median - 0.17961533349999997
# Mean - 1.1733997721534841
# Median - 1.1028458025
# Mean - 2.474491546622095
# Median - 2.4026992905
# Mean - 1.1726026384818948
# Median - 1.1603895175
# Mean - 0.24164413597121703
# Median - 0.24481852
# Mean - 0.2727889887334578
# Median - 0.273101401
# Mean - 0.6931795764020435
# Median - 0.704873812

# %%
#plotting boxplot of pCREB_N grouped by Genotype
update_mice_protein_data.boxplot(column = ["pCREB_N"], showmeans=True, by=["Genotype"])
#plt.show()
# mean = 0.617
# median = 0.56636

# %% [markdown]
# MULTIVARIATE DATA EXPLORATION

# %%
#plotting the distribution of two different proteins together
plt.hist(update_mice_protein_data['AKT_N'], bins=50, alpha=0.5, label='AKT_N',edgecolor= "black", color = "black")
plt.hist(update_mice_protein_data['BRAF_N'], bins=70, alpha=0.5, label='BRAF_N',edgecolor= "black", color = "red")
plt.title("Distribution of AKT_N & BRAF_N")
plt.xlabel("Provided Values")
plt.ylabel("Frequency or Count")
plt.legend(loc='upper right')
plt.show()

# %%
#plotting the distribution of a few different proteins together
k=1
j=0
list = ['ERK_N', 'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N','RSK_N']
for i in update_mice_protein_data.columns[25:30]:
    fig2 = plt.figure(figsize=(17, 14))
    plt.subplot(3,2,k)
    plt.hist(update_mice_protein_data[list[j]], bins=50, alpha=0.5, label=list[j], edgecolor= "black", color = "black")
    plt.hist(update_mice_protein_data[list[j]], bins=70, alpha=0.5, label=list[j+1],edgecolor= "black", color = "red")
    plt.legend(loc='upper right')
    plt.show()
    k+=1
    j+=1

# %%
update_mice_protein_data.boxplot(column=['pCREB_N'],vert=0,showmeans=True,by=['class'])

# %%
list = ['ERK_N', 'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N', 'RSK_N']
j=0
while j<6:
    update_mice_protein_data.boxplot(column=[list[j]],vert=0,showmeans=True,by=['class'])
    j=j+1

# %%
list = ['DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N', 'pBRAF_N',
       'pCAMKII_N', 'pCREB_N', 'pELK_N', 'pERK_N', 'pJNK_N', 'PKCA_N',
       'pMEK_N', 'pNR1_N', 'pNR2A_N', 'pNR2B_N', 'pPKCAB_N', 'pRSK_N', 'AKT_N',
       'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N', 'GSK3B_N', 'JNK_N',
       'MEK_N', 'TRKA_N', 'RSK_N', 'APP_N', 'Bcatenin_N', 'SOD1_N', 'MTOR_N',
       'P38_N', 'pMTOR_N', 'DSCR1_N', 'AMPKA_N', 'NR2B_N', 'pNUMB_N',
       'RAPTOR_N', 'TIAM1_N', 'pP70S6_N', 'NUMB_N', 'P70S6_N', 'pGSK3B_N',
       'pPKCG_N', 'CDK5_N', 'S6_N', 'ADARB1_N', 'AcetylH3K9_N', 'RRP1_N',
       'BAX_N', 'ARC_N', 'ERBB4_N', 'nNOS_N', 'Tau_N', 'GFAP_N', 'GluR3_N',
       'GluR4_N', 'IL1B_N', 'P3525_N', 'pCASP9_N', 'PSD95_N', 'SNCA_N',
       'Ubiquitin_N', 'pGSK3B_Tyr216_N', 'SHH_N', 'BAD_N', 'BCL2_N', 'pS6_N',
       'pCFOS_N', 'SYP_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N', 'CaNA_N']
j=0

while j<77:
    update_mice_protein_data.boxplot(column=[list[j]],vert=0,showmeans=True,by=['class'])
    j=j+1
# Out:
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\tools.py:188: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\tools.py:188: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# ...

# %%
list = ['SOD1_N', 'pCAMKII_N', 'Ubiquitin_N', 'CaNA_N', 'pPKCAB_N', 'pGSK3B_N']
j=0 
while j<6:
    update_mice_protein_data.boxplot(column=[list[j]],vert=0,showmeans=True,by=['class'])
    j=j+1

# %% [markdown]
# DATA MODELLING

# %% [markdown]
# Making a random forest classifier with target variable 'class'

# %%
#Training
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y = update_mice_protein_data['class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=1)

from sklearn.ensemble import RandomForestClassifier
random_forest_clf = RandomForestClassifier(max_depth=12,n_estimators=1000, random_state=1, n_jobs=1)
random_forest_clf_fitted = random_forest_clf.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix, accuracy_score
y_predict = random_forest_clf.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.9884259259259259

# %%
#getting the hyper parameters used by classifier after tuning
print(random_forest_clf.get_params())
# Out:
# {'bootstrap': True, 'class_weight': None, 'criterion': 'gini', 'max_depth': 12, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 1000, 'n_jobs': 1, 'oob_score': False, 'random_state': 1, 'verbose': 0, 'warm_start': False}

# %%
#getting all the important values to series
imp_values = pd.Series(random_forest_clf.feature_importances_,index=X.columns)

# %%
list = ['DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N', 'pBRAF_N',
       'pCAMKII_N', 'pCREB_N', 'pELK_N', 'pERK_N', 'pJNK_N', 'PKCA_N',
       'pMEK_N', 'pNR1_N', 'pNR2A_N', 'pNR2B_N', 'pPKCAB_N', 'pRSK_N', 'AKT_N',
       'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N', 'GSK3B_N', 'JNK_N',
       'MEK_N', 'TRKA_N', 'RSK_N', 'APP_N', 'Bcatenin_N', 'SOD1_N', 'MTOR_N',
       'P38_N', 'pMTOR_N', 'DSCR1_N', 'AMPKA_N', 'NR2B_N', 'pNUMB_N',
       'RAPTOR_N', 'TIAM1_N', 'pP70S6_N', 'NUMB_N', 'P70S6_N', 'pGSK3B_N',
       'pPKCG_N', 'CDK5_N', 'S6_N', 'ADARB1_N', 'AcetylH3K9_N', 'RRP1_N',
       'BAX_N', 'ARC_N', 'ERBB4_N', 'nNOS_N', 'Tau_N', 'GFAP_N', 'GluR3_N',
       'GluR4_N', 'IL1B_N', 'P3525_N', 'pCASP9_N', 'PSD95_N', 'SNCA_N',
       'Ubiquitin_N', 'pGSK3B_Tyr216_N', 'SHH_N', 'BAD_N', 'BCL2_N', 'pS6_N',
       'pCFOS_N', 'SYP_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N', 'CaNA_N']
df = pd.DataFrame(random_forest_clf.feature_importances_,update_mice_protein_data.columns[1:78],columns=['Values'])
print(df)
# Out:
#              Values
# DYRK1A_N   0.027272
# ITSN1_N    0.024591
# BDNF_N     0.006074
# NR1_N      0.006556
# NR2A_N     0.005426
# ...             ...
# SYP_N      0.007322
# H3AcK18_N  0.011838
# EGR1_N     0.004624
# H3MeK4_N   0.005972
# CaNA_N     0.032884
#
# [77 rows x 1 columns]

# %%
df_importance = df[df['Values']>0.0155]

# %%
df_importance.sort_values('Values', ascending=False, inplace=True)
print(df_importance)
# Out:
#                 Values
# SOD1_N        0.058909
# pPKCG_N       0.037580
# pERK_N        0.035993
# APP_N         0.033460
# CaNA_N        0.032884
# Ubiquitin_N   0.030103
# DYRK1A_N      0.027272
# pCAMKII_N     0.026176
# ITSN1_N       0.024591
# pPKCAB_N      0.023523
# P38_N         0.023488
# ARC_N         0.023314
# pS6_N         0.022822
# Tau_N         0.022453
# BRAF_N        0.021110
# pNUMB_N       0.020465
# pP70S6_N      0.020057
# S6_N          0.018893
# pGSK3B_N      0.017598
# AKT_N         0.017350
# AcetylH3K9_N  0.017090
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#I will use a threshold to get the most important attributes(a.k.a proteins here)

#It will be done by creating a selector objcet that will use random forest classifier
#choosing a particular importance
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(random_forest_clf,threshold=0.0155)

#Train
selector.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini', max_depth=12,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=1000, n_jobs=1,
#                                                  oob_score=False,
#                                                  random_state=1, verbose=0,
# ...

# %%
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
random_forest_clf_imp = RandomForestClassifier(max_depth=15,n_estimators=100, random_state=1, n_jobs=1)
#training the classifier with most imp features
random_forest_clf_imp.fit(X_imp_train,y_train)
#predicting the values with important features clf
y_imp_predict = random_forest_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test,y_imp_predict)
# Out:
# 0.9907407407407407

# %% [markdown]
# With a threshold of 0.010, the accuracy is decreased a bit -> accuracy = 0.9652
# With a threshold of 0.020, the accuracy is decreased a bit -> accuracy = 0.9560
# With a threshold of 0.015(mean of the two), the accuracy is -> 0.990740 (better than before)
# Now testing for threshold of 0.016(might increase/decrease/constant) -> 0.990740
# Now testing for threshold of 0.014(might increase/decrease/constant) -> 0.990740
# Now testing for threshold of 0.017(might increase/decrease/constant) -> 0.990740
# Now testing for threshold of 0.013                                   -> 0.96990740
# As the value remains constant when 0.014<threshold<0.017, i will be taking the average value amongst it
# So, threshold = 0.0155

# %% [markdown]
# Used the gridsearchCV and RandomForestRegressor together to get the best feature. As the time taken to train was quite large, around 9 hours, I selected the paramaters manually using the hit and trial method to get max accuracy

# %%
# from sklearn.ensemble import RandomForestRegressor 
# from sklearn.model_selection import GridSearchCV
# #param_grid = {'max_depth': [12]}
# param_grid = {'bootstrap': [True, False],
#  'max_depth': [10,12,14,21, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [1000,2000]}
# ref = RandomForestRegressor()
# grid_search = GridSearchCV(random_forest_clf, param_grid = param_grid, cv=3, n_jobs=-1, verbose = 2)
# grid_search.fit(X_imp_train,y_train)

# grid_search.best_params_

# #rained the model using the above Grid Search Algorithm which took me around 9 hourse to train one model, i.e, 2*12*2*3*3*10 which is 4320 combinations and with cv = 3, there would be 12960 different parameter combination
# #Ran this for once and got a value for max depth to be 12 which gives me the highest accuracy

# %%
#print(grid_search.best_params_)
# {'bootstrap': False,
#  'max_depth': 12,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1000}

# %%
imp_values.nlargest(21).plot(kind='barh',color="red")
plt.show()

# %% [markdown]
# Making a random forest classifier with target variable 'Genotype'

# %%
#making the model for GenoType

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_geno = update_mice_protein_data['Genotype']

from sklearn.model_selection import train_test_split
X_train, X_test, y_geno_train, y_geno_test = train_test_split(X,y_geno,test_size=0.4,random_state=1)

from sklearn.ensemble import RandomForestClassifier
random_forest_clf = RandomForestClassifier(max_depth=12,n_estimators=100, random_state=1, n_jobs=1)

random_forest_clf_fitted = random_forest_clf.fit(X_train, y_geno_train)

from sklearn.metrics import confusion_matrix, accuracy_score
y_geno_predict = random_forest_clf.predict(X_test)
accuracy_score(y_geno_test,y_geno_predict)
#with max_depth 0f 12, i get the most accuracy which is otherwish 0.98148 for values like max_depth = 13,11,14 or defualt
# Out:
# 0.9861111111111112

# %%
#I will use a threshold to get the most important attributes(a.k.a proteins here)

#It will be done by creating a selector objcet that will use random forest classifier
#choosing a particular importance
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(random_forest_clf,threshold=0.003)

#Train
selector.fit(X_train,y_geno_train)

#Storing the most imp proteins in arrays
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini', max_depth=12,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100, n_jobs=1,
#                                                  oob_score=False,
#                                                  random_state=1, verbose=0,
# ...

# %%
df_imp = df[df["Values"]>0.003]
df_imp.shape
# Out:
# (77, 1)

# %%
df_imp.sort_values("Values",ascending=True)
# Out:
#               Values
# pCFOS_N     0.004058
# EGR1_N      0.004624
# MEK_N       0.004633
# Bcatenin_N  0.004860
# pNR2B_N     0.004886
# ...              ...
# CaNA_N      0.032884
# APP_N       0.033460
# pERK_N      0.035993
# pPKCG_N     0.037580
# SOD1_N      0.058909
#
# [77 rows x 1 columns]

# %%
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
random_forest_clf_imp = RandomForestClassifier(max_depth=12,n_estimators=100, random_state=1, n_jobs=1)
#training the classifier with most imp features
random_forest_clf_imp.fit(X_imp_train,y_geno_train)
#predicting the values with important features clf
y_geno_imp_predict = random_forest_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_geno_test,y_geno_imp_predict)
# Out:
# 0.9861111111111112

# %%
#The accuracy value remain same for "Genotype" even after selecting the most imporatant which are atleast 77(basically all the attributes)
#even after building the model over all the attributes the accuracy remains 0.9861111
#Hence we require all the attributes to train our model to achieve max accuracy

# %% [markdown]
# Making a random forest classifier with target variable 'Treatment'

# %%
#Building a model for Treatment

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_treat = update_mice_protein_data['Treatment']

from sklearn.model_selection import train_test_split
X_train, X_test, y_treat_train, y_treat_test = train_test_split(X,y_treat,test_size=0.4,random_state=1)

from sklearn.ensemble import RandomForestClassifier
random_forest_clf = RandomForestClassifier(max_depth=9,n_estimators=100, random_state=1, n_jobs=1)

random_forest_clf_fitted = random_forest_clf.fit(X_train, y_treat_train)

from sklearn.metrics import confusion_matrix, accuracy_score
y_treat_predict = random_forest_clf.predict(X_test)
accuracy_score(y_treat_test,y_treat_predict)
#with max_depth of 9 and above, the accuracy is most which is 0.988425, using default value gives the same accuracy
# Out:
# 0.9884259259259259

# %%
#I will use a threshold to get the most important attributes(a.k.a proteins here)

#It will be done by creating a selector objcet that will use random forest classifier
#choosing a particular importance
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(random_forest_clf,threshold=0.003)

#Train
selector.fit(X_train,y_treat_train)

#Storing the most imp proteins in arrays
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini', max_depth=9,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100, n_jobs=1,
#                                                  oob_score=False,
#                                                  random_state=1, verbose=0,
# ...

# %%
df_imp = df[df["Values"]>0.003]
df_imp.shape
# Out:
# (77, 1)

# %%
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
random_forest_clf_imp = RandomForestClassifier(max_depth=9,n_estimators=100, random_state=1, n_jobs=1)
#training the classifier with most imp features
random_forest_clf_imp.fit(X_imp_train,y_treat_train)
#predicting the values with important features clf
y_treat_imp_predict = random_forest_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_treat_test,y_treat_imp_predict)
# Out:
# 0.9884259259259259

# %%
#The accuracy value remain same for"Treatment" even after selecting the most imporatant which are atleast 77(which are basically all  the attributes)
#even after building the model over all the attributes the accuracy remains 0.9861111
#Hence we require all the attributes to train our model to achieve max accuracy

# %%
# Building a RF classifier for Behavior too

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_behavior = update_mice_protein_data['Behavior']

from sklearn.model_selection import train_test_split
X_train, X_test, y_behavior_train, y_behavior_test = train_test_split(X,y_behavior,test_size=0.4,random_state=1)

from sklearn.ensemble import RandomForestClassifier
random_forest_clf = RandomForestClassifier(max_depth=4,n_estimators=100, random_state=1, n_jobs=1)

random_forest_clf_fitted = random_forest_clf.fit(X_train, y_behavior_train)

from sklearn.metrics import confusion_matrix, accuracy_score
y_behavior_predict = random_forest_clf.predict(X_test)
accuracy_score(y_behavior_test,y_behavior_predict)
# Out:
# 1.0

# %%
#I will use a threshold to get the most important attributes(a.k.a proteins here)

#It will be done by creating a selector objcet that will use random forest classifier
#choosing a particular importance
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(random_forest_clf,threshold=0.003)

#Train
selector.fit(X_train,y_behavior_train)

#Storing the most imp proteins in arrays
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini', max_depth=4,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100, n_jobs=1,
#                                                  oob_score=False,
#                                                  random_state=1, verbose=0,
# ...

# %%
df_imp = df[df["Values"]>0.003]
df_imp.shape
# Out:
# (77, 1)

# %%
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
random_forest_clf_imp = RandomForestClassifier(max_depth=9,n_estimators=100, random_state=1, n_jobs=1)
#training the classifier with most imp features
random_forest_clf_imp.fit(X_imp_train,y_behavior_train)
#predicting the values with important features clf
y_behavior_imp_predict = random_forest_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_behavior_test,y_behavior_imp_predict)
# Out:
# 1.0

# %% [markdown]
# Making a decision tree classifier with target variable 'class'

# %%
#Building a decision tree model for class

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_class_dec = update_mice_protein_data['class']

from sklearn.model_selection import train_test_split
X_train, X_test, y_dec_class_train, y_dec_class_test = train_test_split(X,y_class_dec,test_size=0.2,random_state=1)

from sklearn.tree import DecisionTreeClassifier 
tree_model_1_class = DecisionTreeClassifier(max_depth=12, random_state=1)
tree_model_1_class.fit(X_train,y_dec_class_train)

from sklearn.metrics import confusion_matrix, accuracy_score
y_dec_class_predict = tree_model_1_class.predict(X_test)
accuracy_score(y_dec_class_test,y_dec_class_predict)
# Out:
# 0.8657407407407407

# %%
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(tree_model_1_class,threshold=0.018)

#Train
selector.fit(X_train,y_dec_class_train)
df_imp = df[df["Values"]>0.018]
df_imp.shape
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
tree_model_1_class_clf_imp = DecisionTreeClassifier(max_depth=12, random_state=1)
#training the classifier with most imp features
tree_model_1_class_clf_imp.fit(X_imp_train,y_dec_class_train)
#predicting the values with important features clf
y_dec_class_1_imp_predict = tree_model_1_class_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_dec_class_test,y_dec_class_1_imp_predict)
#max accuracy is achieved by using threshold of 0.006 give 0.88888
#max accuracy is achieved by using threshold of 0.018 gives 0.88888
#i will choose 0.018 as less number of columns would be choosen
#quite a small increase in accuracy though
# Out:
# 0.8888888888888888

# %%
df_imp = df[df["Values"]>0.018]
df_imp.shape
# Out:
# (18, 1)

# %%
imp_values.nlargest(18).plot(kind='barh',color="red")
plt.show()

# %%
#Building a decision tree model for Genotype

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_gen_dec = update_mice_protein_data['Genotype']

from sklearn.model_selection import train_test_split
X_train, X_test, y_dec_gen_train, y_dec_gen_test = train_test_split(X,y_gen_dec,test_size=0.4,random_state=1)

from sklearn.tree import DecisionTreeClassifier 
tree_model_1_gen = DecisionTreeClassifier(max_depth=8, random_state=1)
tree_model_1_gen.fit(X_train,y_dec_gen_train)

from sklearn.metrics import confusion_matrix, accuracy_score
y_dec_gen_predict = tree_model_1_gen.predict(X_test)
accuracy_score(y_dec_gen_test,y_dec_gen_predict)
# Out:
# 0.9143518518518519

# %%
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(tree_model_1_gen,threshold=0.008)

#Train
selector.fit(X_train,y_dec_gen_train)
df_imp = df[df["Values"]>0.007]
df_imp.shape
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
tree_model_1_clf_imp = DecisionTreeClassifier(max_depth=8, random_state=1)
#training the classifier with most imp features
tree_model_1_clf_imp.fit(X_imp_train,y_dec_gen_train)
#predicting the values with important features clf
y_dec_gen_1_imp_predict = tree_model_1_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_dec_gen_test,y_dec_gen_1_imp_predict)
#max accuracy is achived by using threshold of 0.008
#quite a small increase in accuracy though
# Out:
# 0.9166666666666666

# %%
#Building a decision tree model 1

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_treat_dec = update_mice_protein_data['Treatment']

from sklearn.model_selection import train_test_split
X_train, X_test, y_dec_treat_train, y_dec_treat_test = train_test_split(X,y_treat_dec,test_size=0.4,random_state=1)

from sklearn.tree import DecisionTreeClassifier 
tree_model_1_treat = DecisionTreeClassifier(max_depth=9, random_state=1)
tree_model_1_treat.fit(X_train,y_dec_treat_train)
from sklearn.metrics import confusion_matrix, accuracy_score
y_dec_treat_predict = tree_model_1_treat.predict(X_test)
accuracy_score(y_dec_treat_test,y_dec_treat_predict)
# Out:
# 0.8680555555555556

# %%
#Feature Selection
from sklearn.feature_selection import SelectFromModel
selector = SelectFromModel(tree_model_1_treat,threshold=0.020)
#Train
selector.fit(X_train,y_dec_treat_train)
df_imp = df[df["Values"]>0.007]
df_imp.shape
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
tree_model_1_clf_imp = DecisionTreeClassifier(max_depth=9, random_state=1)
#training the classifier with most imp features
tree_model_1_clf_imp.fit(X_imp_train,y_dec_treat_train)
#predicting the values with important features clf
y_dec_treat_1_imp_predict = tree_model_1_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_dec_treat_test,y_dec_treat_1_imp_predict)
#max accuracy is achived by using threshold of 0.020
# Out:
# 0.9027777777777778

# %%
#change after feature selection as we require 54 attributes with threshold 0.007 for the best fit model and tuned parameters

# %%
#Building a decision tree model 2

# %%
#Changing the hyper parameters and the test_size to gain better accuracy
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_treat_dec_2 = update_mice_protein_data['Treatment']

from sklearn.model_selection import train_test_split
X_train, X_test, y_dec_treat_2_train, y_dec_treat_2_test = train_test_split(X,y_treat_dec_2,test_size=0.2,random_state=1)

from sklearn.tree import DecisionTreeClassifier 
tree_model_2_treat = DecisionTreeClassifier(max_depth=11, random_state=1)
tree_model_2_treat.fit(X_train,y_dec_treat_2_train)
from sklearn.metrics import confusion_matrix, accuracy_score
y_dec_treat_2_predict = tree_model_2_treat.predict(X_test)
accuracy_score(y_dec_treat_2_test,y_dec_treat_2_predict)
# Out:
# 0.9259259259259259

# %%
#After feature selection for model tree_model_2_treat_

# %%
#I will use a threshold to get the most important attributes(a.k.a proteins here)

#It will be done by creating a selector objcet that will use random forest classifier
#choosing a particular importance
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(tree_model_2_treat,threshold=0.016
                          )

#Train
selector.fit(X_train,y_dec_treat_2_train)

#Storing the most imp proteins in arrays
df_imp = df[df["Values"]>0.016]
df_imp.shape

#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)

#creating a new classifier with most imp features
tree_model_2_clf_imp = DecisionTreeClassifier(max_depth=11, random_state=1)
#training the classifier with most imp features
tree_model_2_clf_imp.fit(X_imp_train,y_dec_treat_2_train)

#predicting the values with important features clf
y_dec_treat_2_imp_predict = tree_model_2_clf_imp.predict(X_imp_test)

#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_dec_treat_2_test,y_dec_treat_2_imp_predict)

#threshold of 0.016 and 0.017  gives the most accuracy
#as we should be using less features to prevent over fitting, i would be using 0.016
# Out:
# 0.9351851851851852

# %%
#Building a decision tree model

# %%
X = update_mice_protein_data.loc[:, 'DYRK1A_N':'CaNA_N']
y_behavior_dec = update_mice_protein_data['Behavior']

from sklearn.model_selection import train_test_split
X_train, X_test, y_dec_behavior_train, y_dec_behavior_test = train_test_split(X,y_behavior_dec,test_size=0.4,random_state=1)

from sklearn.tree import DecisionTreeClassifier 
tree_model = DecisionTreeClassifier(max_depth=9, random_state=1)
tree_model.fit(X_train,y_dec_behavior_train)
from sklearn.metrics import confusion_matrix, accuracy_score
y_dec_behavior_predict = tree_model.predict(X_test)
accuracy_score(y_dec_behavior_test,y_dec_behavior_predict)
# Out:
# 0.9861111111111112

# %%
#After feature selection

# %%
#I will use a threshold to get the most important attributes(a.k.a proteins here)

#It will be done by creating a selector objcet that will use random forest classifier
#choosing a particular importance
from sklearn.feature_selection import SelectFromModel

selector = SelectFromModel(tree_model,threshold=0.003)

#Train
selector.fit(X_train,y_dec_behavior_train)

#Storing the most imp proteins in arrays
# Out:
# SelectFromModel(estimator=DecisionTreeClassifier(class_weight=None,
#                                                  criterion='gini', max_depth=9,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  presort=False, random_state=1,
#                                                  splitter='best'),
#                 max_features=None, norm_order=1, prefit=False, threshold=0.003)

# %%
df_imp = df[df["Values"]>0.003]
df_imp.shape
# Out:
# (77, 1)

# %%
#creating new data set from the sfm model to test the accuracy with most imp features
X_imp_train = selector.transform(X_train)
X_imp_test = selector.transform(X_test)
#creating a new classifier with most imp features
tree_model_clf_imp = DecisionTreeClassifier(max_depth=9, random_state=1)
#training the classifier with most imp features
tree_model_clf_imp.fit(X_imp_train,y_dec_behavior_train)
#predicting the values with important features clf
y_dec_behavior_imp_predict = tree_model_clf_imp.predict(X_imp_test)
#accuracy score
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_dec_behavior_test,y_dec_behavior_imp_predict)
# Out:
# 0.9930555555555556

# %% [markdown]
# # END OF PROJECT
